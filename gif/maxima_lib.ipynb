# %%
from findmaxima2d import *
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
img_bgr = cv2.imread('C:/Users/shashg/Documents/Frames/24 deg FG 7mg_ml a.jpg')
img_color = img_bgr.copy()
img_color[:,:,2] = np.zeros((img_color.shape[0], img_color.shape[1]))




ranges =  [np.array([112,0,0]) ,np.array([120,255, 255])]
mask = cv2.inRange(cv2.cvtColor(img_color,cv2.COLOR_BGR2HSV), ranges[0], ranges[1])
contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
c = max(contours, key = cv2.contourArea)
x,y,w,h = cv2.boundingRect(c)
cropped = img_color[y:y+h, x:x+w]

img = cv2.cvtColor(img_color, 6)
print(img.shape)
# Out:
# (640, 480)

# %%
local_max = find_local_maxima(img)
y,x, _  = find_maxima(img, local_max, 9)

n = x.tolist()
n.remove(x[0])
print(np.mean(img_color))
plt.imshow(cv2.cvtColor(img_color, 4))
plt.plot(x,y,'ro')
plt.show()
# Out:
# 9.929856770833334

# %%
n
# Out:
# [479]
