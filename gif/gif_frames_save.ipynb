# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from gif_reading import *
from gif_utils import *

# %%
gif_folder = r"C:/Users/shashg/Documents/gifs"
img_folder = r"C:/Users/shashg/Documents/Frames"

# %%
for gif_file in os.listdir(gif_folder):
    gif_filepath = os.path.join(gif_folder, gif_file)
    maxFrame = getMaxFrame(gif_filepath)
    filename = os.path.splitext(gif_file)[0]
    img_file = os.path.join(img_folder, f"{filename}.jpg")
    cv2.imwrite(img_file, maxFrame)

# %%
f = maxFrame.copy()
f[:,:,2] = np.zeros((f.shape[0], f.shape[1]))
f[:,:,1] = np.zeros((f.shape[0], f.shape[1]))
plt.imshow(cv2.cvtColor(f,4))
